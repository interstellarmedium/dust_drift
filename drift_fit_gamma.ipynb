# %% [markdown]
# ### measure drift parameters from the Long disk size measurements

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np
import pandas as pd
from scipy.optimize import fsolve
# %matplotlib inline
# Out:
# /Users/jpw/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
import astropy.constants as c
import astropy.units as u
au = c.au.cgs.value
mH = c.m_p.cgs.value
kB = c.k_B.cgs.value
msun = c.M_sun.cgs.value
G = c.G.cgs.value
mearth = c.M_earth.cgs.value

# %%
colnames = ['Source', 'dist', 'lambda', 'Rmm90', 'RCO90', 'Mdust', 'Lstar', 'Teff', 'Mstar', 'age', 'Ref']
df = pd.read_csv('ALL_combined_table.txt', skiprows=2, header=0, sep='\s+', names=colnames)

# %%
df
# Out:
#                Source  dist  lambda  Rmm90  RCO90  Mdust  Lstar  Teff  Mstar  \
# 0               AS209   121     1.2    127    280    107   1.41  4266   0.83
# 1               CIDA1   136     0.9     38    132      7   0.20  3200   0.19
# 2               CIDA7   136     0.9     20     95      5   0.08  3111   0.15
# 3               CITau   159     1.3    212    520     53   0.81  4277   0.90
# 4               CXTau   128     1.3     29    115      5   0.25  3488   0.38
# 5               CYTau   129     1.3     69    295     63   0.25  3560   0.30
# 6               DLTau   159     1.3    145    596    130   0.65  4277   1.05
# 7               DMTau   145     1.1    178    876     34   0.14  3415   0.55
# 8               DNTau   128     1.3     90    241     43   0.69  3806   0.87
# 9              DoAr25   138     1.2    148    233    119   0.95  4266   0.95
# 10             DoAr33   139     1.2     25     64     17   1.51  4467   1.10
# 11              FPTau   128     1.3     47     74      4   0.16  3273   0.39
# 12              GOTau   144     1.3    134   1014     40   0.21  3516   0.45
# 13              GWLup   155     1.2     91    267     54   0.33  3631   0.46
# 14           HD142666   148     1.2     53    172     67   9.12  7586   1.58
# 15           HD143006   165     1.2     78    153     41   3.80  5623   1.82
# 16           HD163296   101     1.2    137    478    185  16.98  9333   2.04
# 17              IMLup   158     1.2    243    803    160   2.57  4266   0.89
# 18              IQTau   131     1.3    111    220     30   0.21  3690   0.74
# 19  J04202555+2700355   170     0.9     34     59      5   0.07  3091   0.14
# 20  J04334465+2615005   173     0.9     62    164     12   0.12  3098   0.15
# 21  J11004022–7619280   191     1.3    118    273     28   0.10  3270   0.47
# 22  J16000236-4222145   163     1.3    107    266     28   0.17  3270   0.23
# 23  J16083070-3828268   155     1.3     94    394     29   1.82  4900   1.53
# 24               MHO6   142     0.9     55    217     10   0.06  3125   0.17
# 25              MPMus    98     1.3     45    110     45   1.20  5000   1.30
# 26              MYLup   156     1.2     76    192     49   0.87  5129   1.23
# 27              RYLup   158     1.3    121    250     61   1.91  4900   1.53
# 28                SR4   134     1.2     29     82     31   1.17  4074   0.68
# 29              Sz100   137     1.3     39    178      9   0.08  3057   0.14
# 30              Sz111   158     1.3     85    462     39   0.21  3705   0.51
# 31              Sz123   162     1.3     46    146      9   0.13  3705   0.55
# 32              Sz129   161     1.2     68    130     57   0.44  4074   0.83
# 33               Sz65   155     1.3     35    172     14   0.87  4060   0.70
# 34               Sz71   156     1.3     94    218     35   0.33  3632   0.41
# 35               Sz84   152     1.3     53    146      7   0.12  3125   0.27
# 36               Sz98   156     1.3    163    358     51   1.51  4060   0.67
# 37              TWHya    60     1.0     59    184     32   0.34  4070   0.81
# 38              UZTau   131     1.3     84    389     67   0.83  3574   1.20
# 39           V4046Sgr    73     1.1     66    362      4   0.86  4350   1.74
# 40             WaOph6   123     1.2     91    298     62   2.88  4169   0.68
#
#      age                     Ref
# 0    1.0                    Long
# 1    1.0                    Long
# 2    2.0                    Long
# 3    2.5        Semenov,Tripathi
# 4    1.6                    Long
# 5    2.3        Semenov,Tripathi
# 6    3.2                    Long
# 7    3.2                    Long
# 8    0.9        Semenov,Tripathi
# 9    2.0                    Long
# 10   1.6                    Long
# 11   3.2                    Long
# 12   2.0                    Long
# 13   2.0                    Long
# 14  12.6                    Long
# 15   4.0                    Long
# 16  12.6                    Long
# 17   0.5                    Long
# 18   4.2        Semenov,Tripathi
# 19   2.5                    Long
# 20   1.3                    Long
# 21   3.2                    Long
# 22   1.3    Ansdell,Tazzari,Long
# 23   2.5    Ansdell,Tazzari,Long
# 24   2.5                    Long
# 25   8.5                   Ribas
# 26   2.0                    Long
# 27   2.5    Ansdell,Tazzari,Long
# 28   0.8                    Long
# 29   1.6    Ansdell,Tazzari,Long
# 30   5.0    Ansdell,Tazzari,Long
# 31   2.0    Ansdell,Tazzari,Long
# 32   4.0                    Long
# 33   1.3    Ansdell,Tazzari,Long
# 34   2.0  Ansdell,Tazzari,Manara
# 35   1.3    Ansdell,Tazzari,Long
# 36   0.5    Ansdell,Tazzari,Long
# 37   6.3                    Long
# 38   1.3                    Long
# 39  25.1                    Long
# 40   0.3                    Long

# %%
df.loc[0]
# Out:
# Source    AS209
# dist        121
# lambda      1.2
# Rmm90       127
# RCO90       280
# Mdust       107
# Lstar      1.41
# Teff       4266
# Mstar      0.83
# age         1.0
# Ref        Long
# Name: 0, dtype: object

# %%
# Lynden-Bell & Pringle surface density profile for gamma=1
def sigma1(r, sigma0, rc):
    return sigma0 / (r/rc) / np.exp(r/rc)

def logsigma1(r, sigma0, rc):
    return np.log10(sigma0 / (r/rc) / np.exp(r/rc))

# %%
# Lynden-Bell & Pringle surface density profile for input gamma
def sigma_gamma(r, sigma0, rc, gamma=1):
    return sigma0 / (r/rc)**gamma / np.exp((r/rc)**(2-gamma))

def logsigma_gamma(r, sigma0, rc, gamma=1):
    return np.log10(sigma0 / (r/rc)**gamma / np.exp((r/rc)**(2-gamma)))

def logsigma1(r, sigma0, rc):
    return np.log10(sigma0 / (r/rc) / np.exp(r/rc))

# %%
# Powell prescription for the surface density at 1 Myr; all variables in cgs
def powell(v0, rho_s, s, r):
    Myr2seconds = 3.15e13
    Sigma_dust = 2.5 * Myr2seconds * v0 * rho_s * s / r
    return Sigma_dust

# %%
# Trapman prescription for the surface density in g/cm2 at the 90% CO radius for a disk with gas+dust mass M
def trapman(M, L):
    logL = np.log10(L)
    #Sigma_CO = 0.0143 * M**0.34
    Sigma_CO = 10**(-2.15-0.53*logL) * M**(0.30-0.08*logL)
    return Sigma_CO

# %%
def fitsigma1(R, Sigma):
    # solve equation for gamma=1
    Rc = (R[0]-R[1]) / np.log(Sigma[1]*R[1] / (Sigma[0]*R[0]))
    Sigma0 = Sigma[0] * (R[0] / Rc) * np.exp(R[0]/Rc)
    return Sigma0, Rc

# %%
def fitsigma_gamma(R, Sigma, gamma=1):
    # solve equation for input gamma
    gamma2 = 2-gamma
    Rc = ((R[0]**gamma2-R[1]**gamma2) / np.log(Sigma[1]*R[1]**gamma / (Sigma[0]*R[0]**gamma)))**(1/gamma2)
    Sigma0 = Sigma[0] * (R[0] / Rc)**gamma * np.exp((R[0]/Rc)**gamma2)
    return Sigma0, Rc

# %%
def match_mass(t, R, Sigma, Mdust):
    Sigma_drift = Sigma.copy()
    Sigma_drift[0] *= t
    Sigma0, Rc = fitsigma1(R, Sigma_drift)

    x = np.logspace(0, 3, num=30)
    M = 3.747e-4 * np.trapz(2*np.pi*x*sigma1(x, Sigma0, Rc), x)    # earth masses of dust (for g/d=100)

    return M-Mdust

# %%
def match_mass_gamma(t, R, Sigma, Mdust, gamma):
    Sigma_drift = Sigma.copy()
    Sigma_drift[0] *= t
    Sigma0, Rc = fitsigma_gamma(R, Sigma_drift, gamma=gamma)

    x = np.logspace(0, 3, num=30)
    M = 3.747e-4 * np.trapz(2*np.pi*x*sigma1(x, Sigma0, Rc), x)    # earth masses of dust (for g/d=100)

    return M-Mdust

# %%
def toomre(t, R, Sigma, Mstar, Lstar):
    Sigma_drift = Sigma.copy()
    Sigma_drift[0] *= t
    Sigma0, Rc = fitsigma1(R, Sigma_drift)

    x = np.logspace(0, 3, num=30)
    T0 = 82 * (Lstar/0.28)**(2/7) / (Mstar/0.8)**(1/7) 
    T = T0 * x**(-3/7)
    c_s = 5952 * np.sqrt(T)
    Omega = 1.99e-7 * np.sqrt(Mstar / x**3)
    Q = 4.77e6 * c_s * Omega / sigma1(x, Sigma0, Rc)
    Qmin = np.min(Q)

    return Qmin-1

# %%
def mq(R, Sigma0, Rc, Mstar, Lstar):
    # calculate the total mass and Toomre Q profile over R in au
    Sigma_fit = sigma1(R, Sigma0, Rc)

    # integrate Sigma to get total mass
    M = 1.125e-7 * np.trapz(Sigma_fit*2*np.pi*R, R)    # solar masses

    T0 = 82 * (Lstar/0.28)**(2/7) / (Mstar/0.8)**(1/7) 
    T = T0 * R**(-3/7)
    c_s = 5952 * np.sqrt(T)
    Omega = 1.99e-7 * np.sqrt(Mstar / R**3)
    Q = 4.77e6 * c_s * Omega / Sigma_fit

    return M, Q

# %%
def get_data_points(df, iloc):
    Mstar = df['Mstar'][iloc]                           # Msun
    Lstar = df['Lstar'][iloc]                           # Lsun
    T0 = 82 * (Lstar/0.28)**(2/7) / (Mstar/0.8)**(1/7)  # midplane temperature at 1au Powell 2017 equation 2
    #print(T0)
    rho_s = 2.0                                         # g/cm^3
    s = df['lambda'][iloc] / (20*np.pi)                 # grain size in cm

    # dust and CO radii in au
    R_obs = np.array([df['Rmm90'][iloc], df['RCO90'][iloc]])

    # drift speed in cm/s
    T = T0 * (R_obs[0])**(-3/7)
    c_s = np.sqrt(kB * T / (2.33 * mH))
    v_k = np.sqrt(G * Mstar * msun / (R_obs[0] * au))
    v0 = c_s**2 / (2 * v_k)
    print(f'Drift speed = {v0/1e5:5.3f} km/s')

    # dust mass assuming Tdust=20K, in earth masses
    # disk mass for gas/dust=100, in solar masses
    Mdust = df['Mdust'][iloc]
    Mdisk = 100 * Mdust * mearth/msun
    print(f'Dust mass ={Mdust:6.2f} earth masses, total disk mass ={Mdisk:6.4f} solar masses')

    # surface density for dust at 1 Myr and CO at given Mdisk
    Sigma = np.array([powell(v0, rho_s, s, R_obs[0]*au), trapman(Mdisk, Lstar)])

    return(R_obs, Sigma, Mdust)

# %%
def fit_data(df, iloc, gamma=1, plot_to_screen=True, panelplot=False, ax=None):
    source = df['Source'][iloc]
    print(f'Source: {source}')
    Mstar = df['Mstar'][iloc]
    Lstar = df['Lstar'][iloc]
    tstar = df['age'][iloc]
    R_obs, Sigma, Mdust = get_data_points(df, iloc)

    if plot_to_screen:
        plt.ion()
    else:
        plt.ioff()

    if panelplot:
        fontsize = 15
    else:
        fig = plt.figure(figsize=(8,6))
        ax = fig.add_subplot(111)
        fontsize = 16

    ax.set_xscale('log')
    ax.set_yscale('log')
    ax.set_xlim(2, 1e3)
    ax.set_ylim(7e-4, 1e3)
    ax.grid(which='both', alpha=0.3, ls='--') 

    ax2 = ax.twinx()
    ax2.set_yscale('log')
    ax2.set_ylim(0.1, 100)
    ax2.plot([0, 1e3], [1, 1], ':', lw=3, alpha=0.5, color='black')

    if not panelplot:
        ax.set_xlabel('r (au)', fontsize=fontsize)
        ax.set_ylabel(r'$\Sigma_{\rm gas}$ (g cm$^{-2}$)', fontsize=fontsize)
        ax2.set_ylabel('Toomre Q', fontsize=fontsize)

    # make main axis visible above second without hiding it
    ax.set_zorder(1)
    ax.patch.set_visible(False)

    R_plot = np.logspace(0, 3, num=30)
    M_fit = []
    max_iter = 10

    # initial guesses for drif time and max stable disk mass
    t0 = 1.0
    mdisk0 = 0.1
    # some disks need different starting conditions to converge
    if source in ['DoAr25', 'FPTau']:
        t0 = 0.1
        mdisk0 = 0.1
    if source in ['IQTau', 'Sz129', 'Sz71', 'Sz98']:
        t0 = 0.5
        mdisk0 = 0.2
    if source == 'HD143006':
        t0 = 1
        mdisk0 = 0.3
    if source == 'J04202555+2700355':
        t0 = 0.01
        mdisk0 = 0.01
    if source == 'TWHya':
        t0 = 2
        mdisk0 = 0.2

    # solve for the two extreme cases
    for i in range(2):
        if i == 0:
            # disk mass = 100 * dust mass
            color = 'blue'
            #label = str(f"100M_dust = {100*Mdust*mearth/msun:6.3f}")
            label = str(f"M = {100*Mdust*mearth/msun:6.3f}")
            #label = r"$M=100M_{\rm dust}$"
            t_drift = fsolve(match_mass_gamma, t0, args=(R_obs, Sigma, Mdust, gamma))[0]
            td0 = t_drift
        if i == 1:
            # disk is marginally gravitationally stable
            color = 'red'
            iter = 0
            mdisk_converge = False
            while iter < max_iter and not mdisk_converge:
                Sigma_iter = Sigma.copy()
                Sigma_iter[1] = trapman(mdisk0, Lstar)
                t_drift = fsolve(toomre, t0, args=(R_obs, Sigma_iter, Mstar, Lstar))[0]
                Sigma_iter[0] *= t_drift
                Sigma0, Rc = fitsigma_gamma(R_obs, Sigma_iter, gamma=gamma)
                Sigma_fit = sigma_gamma(R_plot, Sigma0, Rc, gamma=gamma)
                mdisk1 = 1.125e-7 * np.trapz(Sigma_fit*2*np.pi*R_plot, R_plot)
                print(f'Trapman iteration {iter}: t_drift={t_drift:6.3f}   Mass change {mdisk0:6.3f} --> {mdisk1:6.3f}')
                if np.abs(mdisk1/mdisk0-1) <  0.99:
                    mdisk_converge = True
                mdisk0 = mdisk1
                iter += 1
            #label = str(f"M(Q=1) = {mdisk0:6.3f}")
            label = str(f"M = {mdisk0:6.3f}")
            #label = r"$Q=1$"
        Sigma_drift = Sigma.copy()
        Sigma_drift[0] *= t_drift
        td1 = t_drift
        if i==1:
            Sigma_drift[1] = trapman(mdisk0, Lstar)

        ax.plot(R_obs, Sigma_drift, 'o', color=color, label=label)
        Sigma0, Rc = fitsigma_gamma(R_obs, Sigma_drift, gamma=gamma)
        M, Q = mq(R_plot, Sigma0, Rc, Mstar, Lstar)
        M_fit.append(M)

        Sigma_plot = sigma_gamma(R_plot, Sigma0, Rc, gamma=gamma)
        tau1 = Sigma_plot > 50
        ax.plot(R_plot, Sigma_plot, '-', color=color)
        ax.plot(R_plot[tau1], Sigma_plot[tau1], '-', color=color, lw=3)
        ax2.plot(R_plot, Q, '--', color=color, zorder=0)
        ax.legend(fontsize=fontsize-6)

        print(f'tdrift ={t_drift:6.3f} Myr, M = {M:6.4f} solar masses, Qmin = {np.min(Q):5.2f}')

    rect = patches.Rectangle((0.02, 0.02), 0.26, 0.22, edgecolor='None', facecolor='white', alpha=0.8, transform=ax.transAxes, zorder=2)
    ax.add_patch(rect)
    ax.text(0.03, 0.14, source, fontsize=fontsize, ha='left', transform=ax.transAxes, zorder=3)
    ax.text(0.03, 0.09, f'Stellar age = {tstar:4.2f} Myr', fontsize=fontsize-4, ha='left', transform=ax.transAxes, zorder=3)
    ax.text(0.03, 0.04, f'Drift times = {td0:3.1f}-{td1:3.1f} Myr', fontsize=fontsize-4, ha='left', transform=ax.transAxes, zorder=3)
    #ax.text(0.03, 0.05, f'Drift factor range = {td0/tstar:4.2f}-{td1/tstar:4.2f}', fontsize=11, ha='left', transform=ax.transAxes, zorder=3)
    #ax.text(0.03, 0.76, f'Q=1 mass factor = {M_fit[1]/M_fit[0]:5.1f}', fontsize=11, ha='left', transform=ax.transAxes, zorder=3)

    if not panelplot:
        fig.tight_layout()
        fig.savefig(source+'.pdf')

    if not plot_to_screen:
        plt.close()

    return td0, td1, *M_fit

# %%
fit_data(df, 37, gamma=1.0, plot_to_screen=True)
# Out:
# Source: TWHya
# Drift speed = 0.008 km/s
# Dust mass = 32.00 earth masses, total disk mass =0.0096 solar masses
# tdrift = 0.439 Myr, M = 0.0096 solar masses, Qmin = 22.39
# Trapman iteration 0: t_drift= 5.772   Mass change  0.200 -->  0.196
# tdrift = 5.772 Myr, M = 0.1962 solar masses, Qmin =  1.00
# (0.4390102614949615,
#  5.772042657496934,
#  0.009607686148919135,
#  0.1961977981636863)

# %%
# DO ALL SOURCES!
f = open('drift_fit_results_gamma.txt', 'w')
f.write("#Source             Age  Drift_min Drift_max  M_min   M_max\n")
f.write("#-----------------------------------------------------------\n")
for i in range(len(df)):
    td_min, td_max, M_min, M_max = fit_data(df, i, gamma=1, plot_to_screen=False)
    f.write(f"{df['Source'][i]:17s} {(df['age'][i]):4.1f}  {td_min:6.3f}     {td_max:6.3f}  {M_min:7.4f} {M_max:7.4f}\n")
f.close()
# Out:
# Source: AS209
# Drift speed = 0.012 km/s
# Dust mass =107.00 earth masses, total disk mass =0.0321 solar masses
# tdrift = 0.165 Myr, M = 0.0321 solar masses, Qmin =  9.22
# Trapman iteration 0: t_drift= 0.708   Mass change  0.100 -->  0.275
# Trapman iteration 1: t_drift= 0.796   Mass change  0.275 -->  0.277
# tdrift = 0.796 Myr, M = 0.2768 solar masses, Qmin =  1.00
# Source: CIDA1
# Drift speed = 0.016 km/s
# Dust mass =  7.00 earth masses, total disk mass =0.0021 solar masses
# tdrift = 0.097 Myr, M = 0.0021 solar masses, Qmin = 47.03
# Trapman iteration 0: t_drift= 2.677   Mass change  0.100 -->  0.087
# tdrift = 2.677 Myr, M = 0.0885 solar masses, Qmin =  0.99
# Source: CIDA7
# Drift speed = 0.014 km/s
# Dust mass =  5.00 earth masses, total disk mass =0.0015 solar masses
# tdrift = 0.186 Myr, M = 0.0015 solar masses, Qmin = 46.07
# Trapman iteration 0: t_drift= 6.456   Mass change  0.100 -->  0.062
# tdrift = 6.456 Myr, M = 0.0632 solar masses, Qmin =  0.97
# Source: CITau
# Drift speed = 0.010 km/s
# Dust mass = 53.00 earth masses, total disk mass =0.0159 solar masses
# tdrift = 0.121 Myr, M = 0.0159 solar masses, Qmin = 23.97
# Trapman iteration 0: t_drift= 1.206   Mass change  0.100 -->  0.334
# Trapman iteration 1: t_drift= 1.374   Mass change  0.334 -->  0.340
# tdrift = 1.374 Myr, M = 0.3390 solar masses, Qmin =  1.00
# Source: CXTau
# Drift speed = 0.011 km/s
# Dust mass =  5.00 earth masses, total disk mass =0.0015 solar masses
# tdrift = 0.103 Myr, M = 0.0015 solar masses, Qmin = 86.75
# Trapman iteration 0: t_drift= 5.177   Mass change  0.100 -->  0.112
# tdrift = 5.177 Myr, M = 0.1115 solar masses, Qmin =  1.01
# Source: CYTau
# Drift speed = 0.013 km/s
# Dust mass = 63.00 earth masses, total disk mass =0.0189 solar masses
# tdrift = 0.454 Myr, M = 0.0189 solar masses, Qmin =  8.54
# Trapman iteration 0: t_drift= 3.078   Mass change  0.100 -->  0.150
# tdrift = 3.078 Myr, M = 0.1469 solar masses, Qmin =  1.03
# Source: DLTau
# Drift speed = 0.008 km/s
# Dust mass =130.00 earth masses, total disk mass =0.0390 solar masses
# tdrift = 0.734 Myr, M = 0.0390 solar masses, Qmin = 10.36
# Trapman iteration 0: t_drift= 5.566   Mass change  0.100 -->  0.365
# Trapman iteration 1: t_drift= 5.948   Mass change  0.365 -->  0.371
# tdrift = 5.948 Myr, M = 0.3712 solar masses, Qmin =  1.00
# Source: DMTau
# Drift speed = 0.008 km/s
# Dust mass = 34.00 earth masses, total disk mass =0.0102 solar masses
# tdrift = 0.176 Myr, M = 0.0102 solar masses, Qmin = 31.78
# Trapman iteration 0: t_drift= 5.161   Mass change  0.100 -->  0.273
# Trapman iteration 1: t_drift= 5.316   Mass change  0.273 -->  0.278
# tdrift = 5.316 Myr, M = 0.2775 solar masses, Qmin =  1.00
# Source: DNTau
# Drift speed = 0.009 km/s
# Dust mass = 43.00 earth masses, total disk mass =0.0129 solar masses
# tdrift = 0.201 Myr, M = 0.0129 solar masses, Qmin = 20.88
# Trapman iteration 0: t_drift= 1.977   Mass change  0.100 -->  0.242
# Trapman iteration 1: t_drift= 2.162   Mass change  0.242 -->  0.245
# tdrift = 2.162 Myr, M = 0.2445 solar masses, Qmin =  1.00
# Source: DoAr25
# Drift speed = 0.010 km/s
# Dust mass =119.00 earth masses, total disk mass =0.0357 solar masses
# tdrift = 0.057 Myr, M = 0.0357 solar masses, Qmin =  7.73
# Trapman iteration 0: t_drift= 0.154   Mass change  0.100 -->  0.258
# Trapman iteration 1: t_drift= 0.183   Mass change  0.258 -->  0.260
# tdrift = 0.183 Myr, M = 0.2591 solar masses, Qmin =  1.00
# Source: DoAr33
# Drift speed = 0.009 km/s
# Dust mass = 17.00 earth masses, total disk mass =0.0051 solar masses
# tdrift = 0.159 Myr, M = 0.0051 solar masses, Qmin = 36.00
# Trapman iteration 0: t_drift= 2.202   Mass change  0.100 -->  0.163
# tdrift = 2.202 Myr, M = 0.1521 solar masses, Qmin =  1.08
# Source: FPTau
# Drift speed = 0.010 km/s
# Dust mass =  4.00 earth masses, total disk mass =0.0012 solar masses
# tdrift = 0.008 Myr, M = 0.0012 solar masses, Qmin = 84.22
# Trapman iteration 0: t_drift= 0.126   Mass change  0.100 -->  0.088
# tdrift = 0.126 Myr, M = 0.0940 solar masses, Qmin =  0.93
# Source: GOTau
# Drift speed = 0.010 km/s
# Dust mass = 40.00 earth masses, total disk mass =0.0120 solar masses
# tdrift = 0.149 Myr, M = 0.0120 solar masses, Qmin = 26.76
# Trapman iteration 0: t_drift= 4.624   Mass change  0.100 -->  0.277
# Trapman iteration 1: t_drift= 4.632   Mass change  0.277 -->  0.283
# tdrift = 4.632 Myr, M = 0.2830 solar masses, Qmin =  1.00
# Source: GWLup
# Drift speed = 0.011 km/s
# Dust mass = 54.00 earth masses, total disk mass =0.0162 solar masses
# tdrift = 0.273 Myr, M = 0.0162 solar masses, Qmin = 11.92
# Trapman iteration 0: t_drift= 1.959   Mass change  0.100 -->  0.177
# tdrift = 1.959 Myr, M = 0.1662 solar masses, Qmin =  1.08
# Source: HD142666
# Drift speed = 0.013 km/s
# Dust mass = 67.00 earth masses, total disk mass =0.0201 solar masses
# tdrift = 0.366 Myr, M = 0.0201 solar masses, Qmin = 20.32
# Trapman iteration 0: t_drift= 3.750   Mass change  0.100 -->  0.373
# Trapman iteration 1: t_drift= 4.050   Mass change  0.373 -->  0.376
# tdrift = 4.050 Myr, M = 0.3757 solar masses, Qmin =  1.00
# Source: HD143006
# Drift speed = 0.009 km/s
# Dust mass = 41.00 earth masses, total disk mass =0.0123 solar masses
# tdrift = 0.067 Myr, M = 0.0123 solar masses, Qmin = 30.61
# Trapman iteration 0: t_drift= 0.594   Mass change  0.300 -->  0.342
# tdrift = 0.594 Myr, M = 0.3324 solar masses, Qmin =  1.03
# Source: HD163296
# Drift speed = 0.014 km/s
# Dust mass =185.00 earth masses, total disk mass =0.0556 solar masses
# tdrift = 0.480 Myr, M = 0.0555 solar masses, Qmin = 12.97
# Trapman iteration 0: t_drift= 3.580   Mass change  0.100 -->  0.662
# Trapman iteration 1: t_drift= 3.907   Mass change  0.662 -->  0.669
# tdrift = 3.907 Myr, M = 0.6682 solar masses, Qmin =  1.00
# Source: IMLup
# Drift speed = 0.014 km/s
# Dust mass =160.00 earth masses, total disk mass =0.0481 solar masses
# tdrift = 0.298 Myr, M = 0.0480 solar masses, Qmin = 10.33
# Trapman iteration 0: t_drift= 1.915   Mass change  0.100 -->  0.448
# Trapman iteration 1: t_drift= 2.102   Mass change  0.448 -->  0.455
# tdrift = 2.102 Myr, M = 0.4548 solar masses, Qmin =  1.00
# Source: IQTau
# Drift speed = 0.007 km/s
# Dust mass = 30.00 earth masses, total disk mass =0.0090 solar masses
# tdrift = 0.096 Myr, M = 0.0090 solar masses, Qmin = 23.54
# Trapman iteration 0: t_drift= 0.885   Mass change  0.200 -->  0.191
# tdrift = 0.885 Myr, M = 0.1937 solar masses, Qmin =  0.99
# Source: J04202555+2700355
# Drift speed = 0.014 km/s
# Dust mass =  5.00 earth masses, total disk mass =0.0015 solar masses
# tdrift = 0.016 Myr, M = 0.0015 solar masses, Qmin = 34.41
# Trapman iteration 0: t_drift= 0.125   Mass change  0.010 -->  0.045
# Trapman iteration 1: t_drift= 0.172   Mass change  0.045 -->  0.046
# tdrift = 0.172 Myr, M = 0.0454 solar masses, Qmin =  1.01
# Source: J04334465+2615005
# Drift speed = 0.017 km/s
# Dust mass = 12.00 earth masses, total disk mass =0.0036 solar masses
# tdrift = 0.076 Myr, M = 0.0036 solar masses, Qmin = 25.21
# Trapman iteration 0: t_drift= 1.040   Mass change  0.100 -->  0.082
# tdrift = 1.040 Myr, M = 0.0843 solar masses, Qmin =  0.97
# Source: J11004022–7619280
# Drift speed = 0.008 km/s
# Dust mass = 28.00 earth masses, total disk mass =0.0084 solar masses
# tdrift = 0.131 Myr, M = 0.0084 solar masses, Qmin = 20.85
# Trapman iteration 0: t_drift= 1.283   Mass change  0.100 -->  0.157
# tdrift = 1.283 Myr, M = 0.1438 solar masses, Qmin =  1.11
# Source: J16000236-4222145
# Drift speed = 0.015 km/s
# Dust mass = 28.00 earth masses, total disk mass =0.0084 solar masses
# tdrift = 0.081 Myr, M = 0.0084 solar masses, Qmin = 16.18
# Trapman iteration 0: t_drift= 0.703   Mass change  0.100 -->  0.124
# tdrift = 0.703 Myr, M = 0.1193 solar masses, Qmin =  1.04
# Source: J16083070-3828268
# Drift speed = 0.008 km/s
# Dust mass = 29.00 earth masses, total disk mass =0.0087 solar masses
# tdrift = 0.247 Myr, M = 0.0087 solar masses, Qmin = 55.29
# Trapman iteration 0: t_drift= 8.038   Mass change  0.100 -->  0.414
# Trapman iteration 1: t_drift= 8.634   Mass change  0.414 -->  0.421
# tdrift = 8.634 Myr, M = 0.4211 solar masses, Qmin =  1.00
# Source: MHO6
# Drift speed = 0.013 km/s
# Dust mass = 10.00 earth masses, total disk mass =0.0030 solar masses
# tdrift = 0.147 Myr, M = 0.0030 solar masses, Qmin = 33.66
# Trapman iteration 0: t_drift= 3.545   Mass change  0.100 -->  0.089
# tdrift = 3.545 Myr, M = 0.0897 solar masses, Qmin =  0.99
# Source: MPMus
# Drift speed = 0.008 km/s
# Dust mass = 45.00 earth masses, total disk mass =0.0135 solar masses
# tdrift = 0.242 Myr, M = 0.0135 solar masses, Qmin = 17.91
# Trapman iteration 0: t_drift= 1.872   Mass change  0.100 -->  0.221
# Trapman iteration 1: t_drift= 2.041   Mass change  0.221 -->  0.223
# tdrift = 2.041 Myr, M = 0.2226 solar masses, Qmin =  1.00
# Source: MYLup
# Drift speed = 0.008 km/s
# Dust mass = 49.00 earth masses, total disk mass =0.0147 solar masses
# tdrift = 0.264 Myr, M = 0.0147 solar masses, Qmin = 19.68
# Trapman iteration 0: t_drift= 2.281   Mass change  0.100 -->  0.263
# Trapman iteration 1: t_drift= 2.528   Mass change  0.263 -->  0.265
# tdrift = 2.528 Myr, M = 0.2650 solar masses, Qmin =  1.00
# Source: RYLup
# Drift speed = 0.009 km/s
# Dust mass = 61.00 earth masses, total disk mass =0.0183 solar masses
# tdrift = 0.108 Myr, M = 0.0183 solar masses, Qmin = 21.24
# Trapman iteration 0: t_drift= 0.735   Mass change  0.100 -->  0.351
# Trapman iteration 1: t_drift= 0.858   Mass change  0.351 -->  0.355
# tdrift = 0.858 Myr, M = 0.3544 solar masses, Qmin =  1.00
# Source: SR4
# Drift speed = 0.012 km/s
# Dust mass = 31.00 earth masses, total disk mass =0.0093 solar masses
# tdrift = 0.257 Myr, M = 0.0093 solar masses, Qmin = 17.30
# Trapman iteration 0: t_drift= 2.296   Mass change  0.100 -->  0.147
# tdrift = 2.296 Myr, M = 0.1405 solar masses, Qmin =  1.05
# Source: Sz100
# Drift speed = 0.015 km/s
# Dust mass =  9.00 earth masses, total disk mass =0.0027 solar masses
# tdrift = 0.109 Myr, M = 0.0027 solar masses, Qmin = 32.55
# Trapman iteration 0: t_drift= 2.746   Mass change  0.100 -->  0.079
# tdrift = 2.746 Myr, M = 0.0794 solar masses, Qmin =  0.99
# Source: Sz111
# Drift speed = 0.009 km/s
# Dust mass = 39.00 earth masses, total disk mass =0.0117 solar masses
# tdrift = 0.354 Myr, M = 0.0117 solar masses, Qmin = 21.07
# Trapman iteration 0: t_drift= 6.328   Mass change  0.100 -->  0.216
# Trapman iteration 1: t_drift= 6.496   Mass change  0.216 -->  0.219
# tdrift = 6.496 Myr, M = 0.2191 solar masses, Qmin =  1.00
# Source: Sz123
# Drift speed = 0.007 km/s
# Dust mass =  9.00 earth masses, total disk mass =0.0027 solar masses
# tdrift = 0.149 Myr, M = 0.0027 solar masses, Qmin = 56.67
# Trapman iteration 0: t_drift= 4.374   Mass change  0.100 -->  0.134
# tdrift = 4.374 Myr, M = 0.1300 solar masses, Qmin =  1.04
# Source: Sz129
# Drift speed = 0.008 km/s
# Dust mass = 57.00 earth masses, total disk mass =0.0171 solar masses
# tdrift = 0.124 Myr, M = 0.0171 solar masses, Qmin = 11.02
# Trapman iteration 0: t_drift= 0.635   Mass change  0.200 -->  0.177
# tdrift = 0.635 Myr, M = 0.1832 solar masses, Qmin =  0.96
# Source: Sz65
# Drift speed = 0.011 km/s
# Dust mass = 14.00 earth masses, total disk mass =0.0042 solar masses
# tdrift = 0.262 Myr, M = 0.0042 solar masses, Qmin = 53.98
# Trapman iteration 0: t_drift= 9.573   Mass change  0.100 -->  0.200
# Trapman iteration 1: t_drift= 9.871   Mass change  0.200 -->  0.201
# tdrift = 9.871 Myr, M = 0.2014 solar masses, Qmin =  1.00
# Source: Sz71
# Drift speed = 0.012 km/s
# Dust mass = 35.00 earth masses, total disk mass =0.0105 solar masses
# tdrift = 0.099 Myr, M = 0.0105 solar masses, Qmin = 16.33
# Trapman iteration 0: t_drift= 0.830   Mass change  0.200 -->  0.158
# tdrift = 0.830 Myr, M = 0.1648 solar masses, Qmin =  0.95
# Source: Sz84
# Drift speed = 0.011 km/s
# Dust mass =  7.00 earth masses, total disk mass =0.0021 solar masses
# tdrift = 0.058 Myr, M = 0.0021 solar masses, Qmin = 53.71
# Trapman iteration 0: t_drift= 1.469   Mass change  0.100 -->  0.099
# tdrift = 1.469 Myr, M = 0.0995 solar masses, Qmin =  1.00
# Source: Sz98
# Drift speed = 0.014 km/s
# Dust mass = 51.00 earth masses, total disk mass =0.0153 solar masses
# tdrift = 0.067 Myr, M = 0.0153 solar masses, Qmin = 20.28
# Trapman iteration 0: t_drift= 0.548   Mass change  0.200 -->  0.280
# tdrift = 0.548 Myr, M = 0.2635 solar masses, Qmin =  1.07
# Source: TWHya
# Drift speed = 0.008 km/s
# Dust mass = 32.00 earth masses, total disk mass =0.0096 solar masses
# tdrift = 0.439 Myr, M = 0.0096 solar masses, Qmin = 22.39
# Trapman iteration 0: t_drift= 5.772   Mass change  0.200 -->  0.196
# tdrift = 5.772 Myr, M = 0.1962 solar masses, Qmin =  1.00
# Source: UZTau
# Drift speed = 0.008 km/s
# Dust mass = 67.00 earth masses, total disk mass =0.0201 solar masses
# tdrift = 0.698 Myr, M = 0.0201 solar masses, Qmin = 18.81
# Trapman iteration 0: t_drift= 9.515   Mass change  0.100 -->  0.340
# Trapman iteration 1: t_drift=10.042   Mass change  0.340 -->  0.345
# tdrift =10.042 Myr, M = 0.3446 solar masses, Qmin =  1.00
# Source: V4046Sgr
# Drift speed = 0.006 km/s
# Dust mass =  4.00 earth masses, total disk mass =0.0012 solar masses
# tdrift = 0.080 Myr, M = 0.0012 solar masses, Qmin = 417.68
# Trapman iteration 0: t_drift=23.193   Mass change  0.100 -->  0.386
# Trapman iteration 1: t_drift=24.305   Mass change  0.386 -->  0.393
# tdrift =24.305 Myr, M = 0.3924 solar masses, Qmin =  1.00
# Source: WaOph6
# Drift speed = 0.016 km/s
# Dust mass = 62.00 earth masses, total disk mass =0.0186 solar masses
# tdrift = 0.214 Myr, M = 0.0186 solar masses, Qmin = 16.67
# Trapman iteration 0: t_drift= 2.004   Mass change  0.100 -->  0.282
# Trapman iteration 1: t_drift= 2.146   Mass change  0.282 -->  0.285
# tdrift = 2.146 Myr, M = 0.2847 solar masses, Qmin =  1.00

# %%
# PANEL PLOT
fig = plt.figure(figsize=(24, 20))
df_indices = range(1,21)
df_indices = range(21,41)
ny = 5
nx = 4
for nplot, iloc in enumerate(df_indices):
    ax = fig.add_subplot(ny, nx, nplot+1)
    ax2 = ax.twinx()
    ax2.set_yticks([])
    #ax2.set_yscale('log')
    #ax2.set_ylim(0.1, 100)
    td_min, td_max, M_min, M_max = fit_data(df, iloc, gamma=1, plot_to_screen=False, panelplot=True, ax=ax)
    if nplot in [16, 17, 18, 19]:
        ax.set_xlabel('r (au)', fontsize=16)
    if nplot in [0, 4, 8, 12, 16]:
        ax.set_ylabel(r'$\Sigma_{\rm gas}$ (g cm$^{-2}$)', fontsize=16)
    if nplot in [3, 7, 11, 15, 19]:
        ax2.yaxis.set_label_coords(1.08,0.0)
        ax2.set_ylabel('Toomre Q', fontsize=16)

fig.tight_layout()
fig.savefig('panelplot_gamma.pdf', dpi=600)
# Out:
# Source: J11004022–7619280
# Drift speed = 0.008 km/s
# Dust mass = 28.00 earth masses, total disk mass =0.0084 solar masses
# tdrift = 0.131 Myr, M = 0.0084 solar masses, Qmin = 20.85
# Trapman iteration 0: t_drift= 1.283   Mass change  0.100 -->  0.157
# tdrift = 1.283 Myr, M = 0.1438 solar masses, Qmin =  1.11
# Source: J16000236-4222145
# Drift speed = 0.015 km/s
# Dust mass = 28.00 earth masses, total disk mass =0.0084 solar masses
# tdrift = 0.081 Myr, M = 0.0084 solar masses, Qmin = 16.18
# Trapman iteration 0: t_drift= 0.703   Mass change  0.100 -->  0.124
# tdrift = 0.703 Myr, M = 0.1193 solar masses, Qmin =  1.04
# Source: J16083070-3828268
# Drift speed = 0.008 km/s
# Dust mass = 29.00 earth masses, total disk mass =0.0087 solar masses
# tdrift = 0.247 Myr, M = 0.0087 solar masses, Qmin = 55.29
# Trapman iteration 0: t_drift= 8.038   Mass change  0.100 -->  0.414
# Trapman iteration 1: t_drift= 8.634   Mass change  0.414 -->  0.421
# tdrift = 8.634 Myr, M = 0.4211 solar masses, Qmin =  1.00
# Source: MHO6
# Drift speed = 0.013 km/s
# Dust mass = 10.00 earth masses, total disk mass =0.0030 solar masses
# tdrift = 0.147 Myr, M = 0.0030 solar masses, Qmin = 33.66
# Trapman iteration 0: t_drift= 3.545   Mass change  0.100 -->  0.089
# tdrift = 3.545 Myr, M = 0.0897 solar masses, Qmin =  0.99
# Source: MPMus
# Drift speed = 0.008 km/s
# Dust mass = 45.00 earth masses, total disk mass =0.0135 solar masses
# tdrift = 0.242 Myr, M = 0.0135 solar masses, Qmin = 17.91
# Trapman iteration 0: t_drift= 1.872   Mass change  0.100 -->  0.221
# Trapman iteration 1: t_drift= 2.041   Mass change  0.221 -->  0.223
# tdrift = 2.041 Myr, M = 0.2226 solar masses, Qmin =  1.00
# Source: MYLup
# Drift speed = 0.008 km/s
# Dust mass = 49.00 earth masses, total disk mass =0.0147 solar masses
# tdrift = 0.264 Myr, M = 0.0147 solar masses, Qmin = 19.68
# Trapman iteration 0: t_drift= 2.281   Mass change  0.100 -->  0.263
# Trapman iteration 1: t_drift= 2.528   Mass change  0.263 -->  0.265
# tdrift = 2.528 Myr, M = 0.2650 solar masses, Qmin =  1.00
# Source: RYLup
# Drift speed = 0.009 km/s
# Dust mass = 61.00 earth masses, total disk mass =0.0183 solar masses
# tdrift = 0.108 Myr, M = 0.0183 solar masses, Qmin = 21.24
# Trapman iteration 0: t_drift= 0.735   Mass change  0.100 -->  0.351
# Trapman iteration 1: t_drift= 0.858   Mass change  0.351 -->  0.355
# tdrift = 0.858 Myr, M = 0.3544 solar masses, Qmin =  1.00
# Source: SR4
# Drift speed = 0.012 km/s
# Dust mass = 31.00 earth masses, total disk mass =0.0093 solar masses
# tdrift = 0.257 Myr, M = 0.0093 solar masses, Qmin = 17.30
# Trapman iteration 0: t_drift= 2.296   Mass change  0.100 -->  0.147
# tdrift = 2.296 Myr, M = 0.1405 solar masses, Qmin =  1.05
# Source: Sz100
# Drift speed = 0.015 km/s
# Dust mass =  9.00 earth masses, total disk mass =0.0027 solar masses
# tdrift = 0.109 Myr, M = 0.0027 solar masses, Qmin = 32.55
# Trapman iteration 0: t_drift= 2.746   Mass change  0.100 -->  0.079
# tdrift = 2.746 Myr, M = 0.0794 solar masses, Qmin =  0.99
# Source: Sz111
# Drift speed = 0.009 km/s
# Dust mass = 39.00 earth masses, total disk mass =0.0117 solar masses
# tdrift = 0.354 Myr, M = 0.0117 solar masses, Qmin = 21.07
# Trapman iteration 0: t_drift= 6.328   Mass change  0.100 -->  0.216
# Trapman iteration 1: t_drift= 6.496   Mass change  0.216 -->  0.219
# tdrift = 6.496 Myr, M = 0.2191 solar masses, Qmin =  1.00
# Source: Sz123
# Drift speed = 0.007 km/s
# Dust mass =  9.00 earth masses, total disk mass =0.0027 solar masses
# tdrift = 0.149 Myr, M = 0.0027 solar masses, Qmin = 56.67
# Trapman iteration 0: t_drift= 4.374   Mass change  0.100 -->  0.134
# tdrift = 4.374 Myr, M = 0.1300 solar masses, Qmin =  1.04
# Source: Sz129
# Drift speed = 0.008 km/s
# Dust mass = 57.00 earth masses, total disk mass =0.0171 solar masses
# tdrift = 0.124 Myr, M = 0.0171 solar masses, Qmin = 11.02
# Trapman iteration 0: t_drift= 0.635   Mass change  0.200 -->  0.177
# tdrift = 0.635 Myr, M = 0.1832 solar masses, Qmin =  0.96
# Source: Sz65
# Drift speed = 0.011 km/s
# Dust mass = 14.00 earth masses, total disk mass =0.0042 solar masses
# tdrift = 0.262 Myr, M = 0.0042 solar masses, Qmin = 53.98
# Trapman iteration 0: t_drift= 9.573   Mass change  0.100 -->  0.200
# Trapman iteration 1: t_drift= 9.871   Mass change  0.200 -->  0.201
# tdrift = 9.871 Myr, M = 0.2014 solar masses, Qmin =  1.00
# Source: Sz71
# Drift speed = 0.012 km/s
# Dust mass = 35.00 earth masses, total disk mass =0.0105 solar masses
# tdrift = 0.099 Myr, M = 0.0105 solar masses, Qmin = 16.33
# Trapman iteration 0: t_drift= 0.830   Mass change  0.200 -->  0.158
# tdrift = 0.830 Myr, M = 0.1648 solar masses, Qmin =  0.95
# Source: Sz84
# Drift speed = 0.011 km/s
# Dust mass =  7.00 earth masses, total disk mass =0.0021 solar masses
# tdrift = 0.058 Myr, M = 0.0021 solar masses, Qmin = 53.71
# Trapman iteration 0: t_drift= 1.469   Mass change  0.100 -->  0.099
# tdrift = 1.469 Myr, M = 0.0995 solar masses, Qmin =  1.00
# Source: Sz98
# Drift speed = 0.014 km/s
# Dust mass = 51.00 earth masses, total disk mass =0.0153 solar masses
# tdrift = 0.067 Myr, M = 0.0153 solar masses, Qmin = 20.28
# Trapman iteration 0: t_drift= 0.548   Mass change  0.200 -->  0.280
# tdrift = 0.548 Myr, M = 0.2635 solar masses, Qmin =  1.07
# Source: TWHya
# Drift speed = 0.008 km/s
# Dust mass = 32.00 earth masses, total disk mass =0.0096 solar masses
# tdrift = 0.439 Myr, M = 0.0096 solar masses, Qmin = 22.39
# Trapman iteration 0: t_drift= 5.772   Mass change  0.200 -->  0.196
# tdrift = 5.772 Myr, M = 0.1962 solar masses, Qmin =  1.00
# Source: UZTau
# Drift speed = 0.008 km/s
# Dust mass = 67.00 earth masses, total disk mass =0.0201 solar masses
# tdrift = 0.698 Myr, M = 0.0201 solar masses, Qmin = 18.81
# Trapman iteration 0: t_drift= 9.515   Mass change  0.100 -->  0.340
# Trapman iteration 1: t_drift=10.042   Mass change  0.340 -->  0.345
# tdrift =10.042 Myr, M = 0.3446 solar masses, Qmin =  1.00
# Source: V4046Sgr
# Drift speed = 0.006 km/s
# Dust mass =  4.00 earth masses, total disk mass =0.0012 solar masses
# tdrift = 0.080 Myr, M = 0.0012 solar masses, Qmin = 417.68
# Trapman iteration 0: t_drift=23.193   Mass change  0.100 -->  0.386
# Trapman iteration 1: t_drift=24.305   Mass change  0.386 -->  0.393
# tdrift =24.305 Myr, M = 0.3924 solar masses, Qmin =  1.00
# Source: WaOph6
# Drift speed = 0.016 km/s
# Dust mass = 62.00 earth masses, total disk mass =0.0186 solar masses
# tdrift = 0.214 Myr, M = 0.0186 solar masses, Qmin = 16.67
# Trapman iteration 0: t_drift= 2.004   Mass change  0.100 -->  0.282
# Trapman iteration 1: t_drift= 2.146   Mass change  0.282 -->  0.285
# tdrift = 2.146 Myr, M = 0.2847 solar masses, Qmin =  1.00
